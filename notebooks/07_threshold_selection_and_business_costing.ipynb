# %% [markdown]
# # 07 - Threshold Selection and Business Costing
#
# This notebook will be developed in the next phase of the project.

# %% [markdown]
# The goal is to keep the repository professional and build the analysis step by step rather than dumping all work into one notebook.
